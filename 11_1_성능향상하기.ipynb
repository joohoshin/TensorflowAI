# %% [markdown]
# <a href="https://colab.research.google.com/github/joohoshin/TensorflowAI/blob/main/11_1_%EC%84%B1%EB%8A%A5%ED%96%A5%EC%83%81%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# fasion mnist 정확도를 향상 시켜봅시다

# %%
import tensorflow as tf
import numpy as np

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap='gray')
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
num_classes = 10

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train/255
x_test = x_test/255

from tensorflow.keras import layers, models

model = models.Sequential()
model.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPool2D(2,2))
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

epochs = 10
history = model.fit(x_train, y_train, batch_size=64,
          epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4719616
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 4,730,698
# Trainable params: 4,730,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 938/938 [==============================] - 7s 5ms/step - loss: 0.5612 - acc: 0.7982 - val_loss: 0.3305 - val_acc: 0.8794
# Epoch 2/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.3001 - acc: 0.8899 - val_loss: 0.2938 - val_acc: 0.8911
# Epoch 3/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2562 - acc: 0.9053 - val_loss: 0.2681 - val_acc: 0.9016
# Epoch 4/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2187 - acc: 0.9180 - val_loss: 0.2458 - val_acc: 0.9108
# Epoch 5/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1952 - acc: 0.9266 - val_loss: 0.2489 - val_acc: 0.9125
# Epoch 6/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1844 - acc: 0.9289 - val_loss: 0.2585 - val_acc: 0.9067
# Epoch 7/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1582 - acc: 0.9421 - val_loss: 0.2535 - val_acc: 0.9145
# Epoch 8/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1442 - acc: 0.9447 - val_loss: 0.2535 - val_acc: 0.9138
# Epoch 9/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1264 - acc: 0.9524 - val_loss: 0.2606 - val_acc: 0.9158
# Epoch 10/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1166 - acc: 0.9547 - val_loss: 0.2570 - val_acc: 0.9185

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['train', 'test'], loc='upper left')

# %%
y_pred = model.predict(x_test)

# %%
y_pred.shape
# Out:
# (10000, 10)

# %%
y_pred = y_pred.argmax(axis = 1)

# %%
y_pred
# Out:
# array([9, 2, 1, ..., 8, 1, 5])

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
y_true = y_test.argmax(axis = 1)

# %%
import pandas as pd 
df = pd.DataFrame({'true_y':y_true, 'pred_y':y_pred})

# %%
df
# Out:
#       true_y  pred_y
# 0          9       9
# 1          2       2
# 2          1       1
# 3          1       1
# 4          6       6
# ...      ...     ...
# 9995       9       9
# 9996       1       1
# 9997       8       8
# 9998       1       1
# 9999       5       5
#
# [10000 rows x 2 columns]

# %%
df['wrong'] = df.true_y != df.pred_y

# %%
df[df['wrong']]
# Out:
#       true_y  pred_y  wrong
# 23         9       5   True
# 40         6       0   True
# 42         3       6   True
# 43         7       9   True
# 67         3       4   True
# ...      ...     ...    ...
# 9969       8       1   True
# 9972       2       6   True
# 9977       6       0   True
# 9989       4       6   True
# 9991       6       0   True
#
# [815 rows x 3 columns]

# %%
df['true_label'] = df.true_y.apply(lambda x: class_names[x])
df['pred_label'] = df.pred_y.apply(lambda x: class_names[x])

# %%
df
# Out:
#       true_y  pred_y  wrong  true_label  pred_label
# 0          9       9  False  Ankle boot  Ankle boot
# 1          2       2  False    Pullover    Pullover
# 2          1       1  False     Trouser     Trouser
# 3          1       1  False     Trouser     Trouser
# 4          6       6  False       Shirt       Shirt
# ...      ...     ...    ...         ...         ...
# 9995       9       9  False  Ankle boot  Ankle boot
# 9996       1       1  False     Trouser     Trouser
# 9997       8       8  False         Bag         Bag
# 9998       1       1  False     Trouser     Trouser
# 9999       5       5  False      Sandal      Sandal
#
# [10000 rows x 5 columns]

# %%
wrong = df[df['wrong']]

# %%
wrong
# Out:
#       true_y  pred_y  wrong  true_label   pred_label
# 23         9       5   True  Ankle boot       Sandal
# 40         6       0   True       Shirt  T-shirt/top
# 42         3       6   True       Dress        Shirt
# 43         7       9   True     Sneaker   Ankle boot
# 67         3       4   True       Dress         Coat
# ...      ...     ...    ...         ...          ...
# 9969       8       1   True         Bag      Trouser
# 9972       2       6   True    Pullover        Shirt
# 9977       6       0   True       Shirt  T-shirt/top
# 9989       4       6   True        Coat        Shirt
# 9991       6       0   True       Shirt  T-shirt/top
#
# [815 rows x 5 columns]

# %%
wrong.value_counts('true_label')
# Out:
# true_label
# Shirt          224
# Coat           157
# T-shirt/top    142
# Pullover       132
# Dress           62
# Ankle boot      35
# Sneaker         22
# Trouser         17
# Bag             14
# Sandal          10
# dtype: int64

# %%
wrong.query('true_label=="Shirt"').value_counts('pred_label')
# Out:
# pred_label
# T-shirt/top    99
# Pullover       45
# Coat           45
# Dress          32
# Bag             2
# Trouser         1
# dtype: int64

# %%
wrong.query('true_label=="Shirt" & pred_label == "T-shirt/top"')
# Out:
#       true_y  pred_y  wrong true_label   pred_label
# 40         6       0   True      Shirt  T-shirt/top
# 586        6       0   True      Shirt  T-shirt/top
# 971        6       0   True      Shirt  T-shirt/top
# 977        6       0   True      Shirt  T-shirt/top
# 1559       6       0   True      Shirt  T-shirt/top
# ...      ...     ...    ...        ...          ...
# 9644       6       0   True      Shirt  T-shirt/top
# 9714       6       0   True      Shirt  T-shirt/top
# 9729       6       0   True      Shirt  T-shirt/top
# 9977       6       0   True      Shirt  T-shirt/top
# 9991       6       0   True      Shirt  T-shirt/top
#
# [99 rows x 5 columns]

# %%
plt.imshow(x_test[40,:,:,0], cmap='gray')

# %%
class_names[y_test[40].argmax()]
# Out:
# 'Shirt'

# %%
plt.imshow(x_test[586,:,:,0], cmap='gray')
