# %% [markdown]
# <a href="https://colab.research.google.com/github/joohoshin/TensorflowAI/blob/main/12_1_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# L1, L2 Regularization을 통해 Overfitting을 줄일 수 있습니다

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
# fashion mnist로 비교해봅시다

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']     

epochs = 20

# %%
num_classes = 10

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train/255
x_test = x_test/255

from tensorflow.keras import layers, models

model = models.Sequential()
model.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPool2D(2,2))
model.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model.add(layers.MaxPool2D(2,2))
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history = model.fit(x_train, y_train, batch_size=32, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 1,111,946
# Trainable params: 1,111,946
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 39s 3ms/step - loss: 0.6244 - acc: 0.7713 - val_loss: 0.3270 - val_acc: 0.8804
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3135 - acc: 0.8855 - val_loss: 0.3010 - val_acc: 0.8903
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2624 - acc: 0.9015 - val_loss: 0.3792 - val_acc: 0.8535
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2358 - acc: 0.9143 - val_loss: 0.2710 - val_acc: 0.9009
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2087 - acc: 0.9228 - val_loss: 0.2745 - val_acc: 0.9063
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1860 - acc: 0.9298 - val_loss: 0.2698 - val_acc: 0.9051
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1763 - acc: 0.9332 - val_loss: 0.2624 - val_acc: 0.9148
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1615 - acc: 0.9393 - val_loss: 0.2845 - val_acc: 0.9063
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1472 - acc: 0.9435 - val_loss: 0.2800 - val_acc: 0.9135
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1342 - acc: 0.9482 - val_loss: 0.2872 - val_acc: 0.9113
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1279 - acc: 0.9521 - val_loss: 0.3174 - val_acc: 0.9089
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1123 - acc: 0.9574 - val_loss: 0.3222 - val_acc: 0.9134
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1077 - acc: 0.9601 - val_loss: 0.3562 - val_acc: 0.9110
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1051 - acc: 0.9620 - val_loss: 0.3420 - val_acc: 0.9139
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0946 - acc: 0.9640 - val_loss: 0.3272 - val_acc: 0.9169
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0925 - acc: 0.9656 - val_loss: 0.3618 - val_acc: 0.9115
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0869 - acc: 0.9679 - val_loss: 0.3772 - val_acc: 0.9067
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0877 - acc: 0.9677 - val_loss: 0.4544 - val_acc: 0.9076
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0747 - acc: 0.9720 - val_loss: 0.4205 - val_acc: 0.9167
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0765 - acc: 0.9718 - val_loss: 0.4574 - val_acc: 0.9130

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'test'], loc='upper left')

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model2.add(layers.MaxPool2D(2,2))
model2.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model2.add(layers.MaxPool2D(2,2))
model2.add(layers.Flatten())
model2.add(layers.Dense(1024, activation='relu'))
model2.add(layers.Dense(512, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))
model2.summary()

model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history2 = model2.fit(x_train, y_train, batch_size=32,
          epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,631,626
# Trainable params: 1,631,626
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5804 - acc: 0.7856 - val_loss: 0.3459 - val_acc: 0.8788
# Epoch 2/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2917 - acc: 0.8927 - val_loss: 0.2764 - val_acc: 0.8964
# Epoch 3/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2431 - acc: 0.9087 - val_loss: 0.2718 - val_acc: 0.9027
# Epoch 4/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2043 - acc: 0.9258 - val_loss: 0.2798 - val_acc: 0.9050
# Epoch 5/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1798 - acc: 0.9301 - val_loss: 0.2710 - val_acc: 0.9079
# Epoch 6/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1600 - acc: 0.9396 - val_loss: 0.3184 - val_acc: 0.9063
# Epoch 7/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1471 - acc: 0.9437 - val_loss: 0.3158 - val_acc: 0.9018
# Epoch 8/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1243 - acc: 0.9533 - val_loss: 0.3261 - val_acc: 0.9035
# Epoch 9/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1154 - acc: 0.9568 - val_loss: 0.3591 - val_acc: 0.9064
# Epoch 10/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0981 - acc: 0.9630 - val_loss: 0.3417 - val_acc: 0.9129
# Epoch 11/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0866 - acc: 0.9671 - val_loss: 0.3553 - val_acc: 0.9118
# Epoch 12/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0796 - acc: 0.9701 - val_loss: 0.4703 - val_acc: 0.9036
# Epoch 13/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0693 - acc: 0.9734 - val_loss: 0.4283 - val_acc: 0.9150
# Epoch 14/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0696 - acc: 0.9740 - val_loss: 0.4143 - val_acc: 0.9131
# Epoch 15/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0637 - acc: 0.9764 - val_loss: 0.4798 - val_acc: 0.9164
# Epoch 16/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0621 - acc: 0.9772 - val_loss: 0.4911 - val_acc: 0.9104
# Epoch 17/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0535 - acc: 0.9807 - val_loss: 0.5443 - val_acc: 0.9075
# Epoch 18/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0543 - acc: 0.9811 - val_loss: 0.5603 - val_acc: 0.9146
# Epoch 19/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0417 - acc: 0.9849 - val_loss: 0.5805 - val_acc: 0.9094
# Epoch 20/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0449 - acc: 0.9845 - val_loss: 0.6495 - val_acc: 0.9112

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.legend(['train', 'test','train2', 'test2'], loc='upper left')

# %%
model3 = models.Sequential()
model3.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model3.add(layers.MaxPool2D(2,2))
model3.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model3.add(layers.MaxPool2D(2,2))
model3.add(layers.Flatten())
model3.add(layers.Dense(1024,kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model3.add(layers.Dense(512,kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))
model3.summary()

model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history3 = model3.fit(x_train, y_train, batch_size=32,
          epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,631,626
# Trainable params: 1,631,626
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.9871 - acc: 0.7688 - val_loss: 0.4601 - val_acc: 0.8647
# Epoch 2/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4146 - acc: 0.8794 - val_loss: 0.3745 - val_acc: 0.8917
# Epoch 3/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3414 - acc: 0.8997 - val_loss: 0.3445 - val_acc: 0.8978
# Epoch 4/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3093 - acc: 0.9057 - val_loss: 0.3210 - val_acc: 0.9013
# Epoch 5/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2857 - acc: 0.9127 - val_loss: 0.3184 - val_acc: 0.9017
# Epoch 6/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2637 - acc: 0.9190 - val_loss: 0.3038 - val_acc: 0.9035
# Epoch 7/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2481 - acc: 0.9225 - val_loss: 0.3140 - val_acc: 0.8974
# Epoch 8/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2385 - acc: 0.9284 - val_loss: 0.3032 - val_acc: 0.9025
# Epoch 9/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2262 - acc: 0.9331 - val_loss: 0.2881 - val_acc: 0.9093
# Epoch 10/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2163 - acc: 0.9351 - val_loss: 0.3012 - val_acc: 0.9090
# Epoch 11/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2136 - acc: 0.9346 - val_loss: 0.2950 - val_acc: 0.9114
# Epoch 12/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2053 - acc: 0.9395 - val_loss: 0.2947 - val_acc: 0.9100
# Epoch 13/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1909 - acc: 0.9443 - val_loss: 0.3008 - val_acc: 0.9077
# Epoch 14/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1872 - acc: 0.9460 - val_loss: 0.3101 - val_acc: 0.9083
# Epoch 15/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1797 - acc: 0.9479 - val_loss: 0.3263 - val_acc: 0.9026
# Epoch 16/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1784 - acc: 0.9494 - val_loss: 0.3055 - val_acc: 0.9082
# Epoch 17/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1706 - acc: 0.9508 - val_loss: 0.3163 - val_acc: 0.9058
# Epoch 18/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1696 - acc: 0.9515 - val_loss: 0.3063 - val_acc: 0.9092
# Epoch 19/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1614 - acc: 0.9549 - val_loss: 0.3365 - val_acc: 0.9026
# Epoch 20/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1586 - acc: 0.9562 - val_loss: 0.3234 - val_acc: 0.9034

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.legend(['train', 'test'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.legend(['train1', 'test1','train3', 'test3'], loc='upper left')

# %%
plt.plot(history3.history['acc'])
plt.plot(history3.history['val_acc'])
plt.legend(['train', 'test'], loc='upper left')
