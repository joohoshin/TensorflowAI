# %% [markdown]
# <a href="https://colab.research.google.com/github/joohoshin/TensorflowAI/blob/main/4_4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%9D%BD%EA%B8%B0_%EC%93%B0%EA%B8%B0(Colab).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 데이터 읽기
# * pandas 에서는 read_csv() 함수를 통해 csv 및 txt 파일 데이터를 손쉽게 읽을 수 있습니다.
# * https://data.seoul.go.kr/dataList/10280/C/2/datasetView.do;jsessionid=F14193A6776D39EE6FAD5343D0DFFD74.new_portal-svr-21

# %% [markdown]
# * 위의 싸이트에서 txt 파일을 받으면 tab으로 데이터가 구분된 파일입니다.
# * 이 파일을 구글 드라이브의 폴더에 업로드하고 불러봅시다

# %%
# 구글 드라이브 연동을 위해 필요
from google.colab import drive
drive.mount('/g') #구글 드라이브를 임의의 명칭으로 지정합니다
# 구글 로그인을 위한 인증코드를 받아서 입력해줍니다
# Out:
# Mounted at /g

# %%
# !ls /g
# Out:
# MyDrive

# %%
# !ls '/g/My Drive/Tensorflow AI'
# Out:
# '아파트(매매)__실거래가_20210227120005.csv'   5_1_조건_검색.ipynb
#  2_1_Variable.ipynb			      5_2_loc,_iloc.ipynb
#  2_2_Input.ipynb			      5_3_데이터_추가,_삭제.ipynb
#  2_3_If.ipynb				      6_1_Apply.ipynb
#  2_4_for.ipynb				      6_2_Pivot_table.ipynb
#  2_5_datetime.ipynb			      6_3_merge.ipynb
#  2_6_random.ipynb			      6_4_Statsmodel.ipynb
#  3_1_List.ipynb				      7_1_MNIST.ipynb
#  3_2_Dictionary.ipynb			      7_2_Mnist2.ipynb
#  3_3_Function.ipynb			     '7_3_Fashion MNIST.ipynb'
#  3_4_global.ipynb			      AppleStore.csv
#  4_1_Numpy1.ipynb			      appleStore_description.csv
#  4_2_Numpy2.ipynb			      grade.csv
#  4_3_Pandas.ipynb			      report.txt
# '4_4_데이터_읽기_쓰기(Colab).ipynb'

# %% [markdown]
# * 이경우에는 탭으로 데이터가 구분되어 있어 옵션에 sep = '\t'를 넣어주면 됩니다
# * seperator가 탭이라는 뜻입니다
# * 인코딩은 기본적으로 utf8로 읽어옵니다.
# * 윈도우 환경에서 엑셀로 저장한 파일은 보통 cp949 인코딩을 사용합니다.

# %%
import pandas as pd
data = pd.read_csv('/g/My Drive/Tensorflow AI/report.txt', sep = '\t' ) #csv 파일의 경우 기본옵션이므로 sep='\t'가 필요 없습니다
# data = pd.read_csv('/g/My Drive/Tensorflow AI/report.txt', sep = '\t', encoding = 'cp949' ) 인코딩이 cp949로 된 파일은 옵션을 주어야 합니다.

# %%
data
# Out:
#       기간    대분류            분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0   2019    서울시           서울시  ...      37.3                5.2   1.4
# 1   2019     성별            남자  ...      32.4                4.9   1.1
# 2   2019     성별            여자  ...      41.0                5.4   1.7
# 3   2019    연령별           10대  ...      32.6                3.5     -
# 4   2019    연령별           20대  ...      38.8                6.4   0.1
# 5   2019    연령별           30대  ...      27.3                4.5   0.2
# 6   2019    연령별           40대  ...      35.5                3.3   0.4
# 7   2019    연령별           50대  ...      36.8                5.6   0.8
# 8   2019    연령별        60대 이상  ...      48.7                6.6   5.6
# 9   2019    학력별         중졸 이하  ...      48.6                7.3   8.5
# 10  2019    학력별         고졸 이하  ...      38.6                5.5   0.7
# 11  2019    학력별         대졸 이하  ...      34.0                4.6   0.3
# ...

# %% [markdown]
# * 데이터가 길 때에는 .head(), .tail()등을 사용해서 처음과 마지막 데이터를 확인할 수 있습니다

# %%
data.head(20)
# Out:
#       기간    대분류            분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0   2019    서울시           서울시  ...      37.3                5.2   1.4
# 1   2019     성별            남자  ...      32.4                4.9   1.1
# 2   2019     성별            여자  ...      41.0                5.4   1.7
# 3   2019    연령별           10대  ...      32.6                3.5     -
# 4   2019    연령별           20대  ...      38.8                6.4   0.1
# 5   2019    연령별           30대  ...      27.3                4.5   0.2
# 6   2019    연령별           40대  ...      35.5                3.3   0.4
# 7   2019    연령별           50대  ...      36.8                5.6   0.8
# 8   2019    연령별        60대 이상  ...      48.7                6.6   5.6
# 9   2019    학력별         중졸 이하  ...      48.6                7.3   8.5
# 10  2019    학력별         고졸 이하  ...      38.6                5.5   0.7
# 11  2019    학력별         대졸 이하  ...      34.0                4.6   0.3
# ...

# %%
data.tail(15)
# Out:
#       기간   대분류    분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 37  2019   노원구   노원구  ...      30.1                1.9  7.4
# 38  2019   은평구   은평구  ...      34.3                6.4  0.5
# 39  2019  서대문구  서대문구  ...      21.9                5.3    1
# 40  2019   마포구   마포구  ...      35.8                3.2  1.5
# 41  2019   양천구   양천구  ...      17.9                4.1  0.1
# 42  2019   강서구   강서구  ...      50.5                4.3    1
# 43  2019   구로구   구로구  ...      39.0                2.9  1.3
# 44  2019   금천구   금천구  ...      37.6                2.3  1.7
# 45  2019  영등포구  영등포구  ...      33.9                5.4    -
# 46  2019   동작구   동작구  ...      31.1                7.6    -
# 47  2019   관악구   관악구  ...      34.2                6.1    1
# 48  2019   서초구   서초구  ...      36.6                3.3  1.8
# 49  2019   강남구   강남구  ...      46.4                5.2  1.6
# 50  2019   송파구   송파구  ...      39.4                4.8    1
# 51  2019   강동구   강동구  ...      32.4                8.4  2.3
#
# ...

# %%
data.head()
# Out:
#      기간  대분류   분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0  2019  서울시  서울시  ...      37.3                5.2  1.4
# 1  2019   성별   남자  ...      32.4                4.9  1.1
# 2  2019   성별   여자  ...      41.0                5.4  1.7
# 3  2019  연령별  10대  ...      32.6                3.5    -
# 4  2019  연령별  20대  ...      38.8                6.4  0.1
#
# [5 rows x 9 columns]

# %% [markdown]
# * 특정 위치를 보려면 df[start:end] end 미포함입니다

# %%
data[3:10]
# Out:
#      기간  대분류      분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 3  2019  연령별     10대  ...      32.6                3.5    -
# 4  2019  연령별     20대  ...      38.8                6.4  0.1
# 5  2019  연령별     30대  ...      27.3                4.5  0.2
# 6  2019  연령별     40대  ...      35.5                3.3  0.4
# 7  2019  연령별     50대  ...      36.8                5.6  0.8
# 8  2019  연령별  60대 이상  ...      48.7                6.6  5.6
# 9  2019  학력별   중졸 이하  ...      48.6                7.3  8.5
#
# [7 rows x 9 columns]

# %% [markdown]
# * 데이터 값들의 평균값 등 통계 치를 확인할때에는 .describe()을 사용합니다

# %%
data.describe()
# Out:
#            기간  운동을 할 충분한 시간이 없어서  ...   운동을 싫어해서  운동을 할 충분한 비용이 없어서
# count    52.0          52.000000  ...  52.000000          52.000000
# mean   2019.0          46.267308  ...  37.153846           5.163462
# std       0.0          10.723709  ...   8.666217           2.020001
# min    2019.0          10.700000  ...  17.900000           0.900000
# 25%    2019.0          42.775000  ...  32.550000           4.075000
# 50%    2019.0          46.900000  ...  35.850000           5.250000
# 75%    2019.0          52.100000  ...  39.775000           6.250000
# max    2019.0          69.800000  ...  68.100000          10.900000
#
# [8 rows x 6 columns]

# %% [markdown]
# * numpy와 마찬가지로 mean(), max() 등의 통계함수를 사용할 수 있습니다
# * 컬럼을 지정하려면 dict와 마찬가지로 df['컬럼명']을 사용하면 됩니다

# %%
data.mean()
# Out:
# 기간                   2019.000000
# 운동을 할 충분한 시간이 없어서      46.267308
# 함께 운동을 할 사람이 없어서        5.103846
# 운동을 할 만한 장소가 없어서        4.655769
# 운동을 싫어해서               37.153846
# 운동을 할 충분한 비용이 없어서       5.163462
# dtype: float64

# %%
data['기간'].max()
# Out:
# 2019

# %%
data['기간'].min()
# Out:
# 2019

# %% [markdown]
# * pandas 에서 데이터를 읽어올때 데이터 타입을 자동으로 지정합니다.
# * 확인을 하기 위해서는 .dtypes를 사용합니다

# %%
data.dtypes
# Out:
# 기간                     int64
# 대분류                   object
# 분류                    object
# 운동을 할 충분한 시간이 없어서    float64
# 함께 운동을 할 사람이 없어서     float64
# 운동을 할 만한 장소가 없어서     float64
# 운동을 싫어해서             float64
# 운동을 할 충분한 비용이 없어서    float64
# 기타                    object
# dtype: object

# %% [markdown]
# * 문자는 object라고 나오고 숫자는 int, float이 나오는데, 뒤에 숫자가 붙습니다
# * 이것은 메모리 사이즈이며 숫자가 크면 더 많은 자리수를 저장할 수 있습니다
# * 기본적으로는 64로 저장됩니다
